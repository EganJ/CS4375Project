# %%
from data import loaders
from fcnn import SimpleFCN
from loss import DiceLoss
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
net = SimpleFCN(dim_in=1, dim_out=1)

loader = DataLoader(loaders.AitexDataset(), batch_size = 5, shuffle=True)

loss_fn = DiceLoss()

# %%
for x, y in tqdm(loader):
    pass
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]

# %%
for x, y, in tqdm(loader):
    pred = net(x)
    loss = loss_fn(pred, y)
    print(loss)
    break
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# tensor(0.9984, grad_fn=<RsubBackward1>)

# %%
def plot_img(arr):
    if len(arr.shape) > 2:
        arr = arr[0]
    plt.figure()
    plt.imshow(arr, cmap="gray")
    plt.show()
    plt.close()

# %%
plot_img(x[0].detach())
plot_img(y[0].detach())
plot_img(pred[0].detach())

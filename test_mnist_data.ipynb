# %%
from data import loaders
from fcnn import SimpleFCN
from loss import DiceLoss
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
net = SimpleFCN(dim_in=1, dim_out=11)

loader = DataLoader(loaders.SegmentationMnistDataset(), batch_size = 5, shuffle=True)

loss_fn = DiceLoss()

# %%
for x, y in tqdm(loader):
    pass
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]

# %%
for x, y, in tqdm(loader):
    pred = net(x)
    loss = loss_fn(pred, y)
    print(loss)
    break
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
# tensor(0.9597, grad_fn=<RsubBackward1>)

# %%
def plot_img(arr):
    if len(arr.shape) > 2:
        arr = arr[0]
    plt.figure()
    plt.imshow(arr, cmap="gray", vmin = 0, vmax = 1)
    plt.show()
    plt.close()

# %%
i = 2
plot_img(x[i].detach())
for j in range(11):
    plot_img(y[i][j].detach())
plot_img(pred[0].detach())

# %%
print(y[0].max())
# Out:
# tensor(1.)
